# %%
#SKIP_COMPARE_OUTPUT
import pixiedust
# Out:
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.9</span>
#         </div>
# Pixiedust database opened successfully

# %%
from bokeh.sampledata.olympics2014 import data
from pandas.io.json import json_normalize

df = json_normalize(data['data'])

# try:
#     from bkcharts.utils import df_from_json
# except ImportError:
#     from bokeh.charts.utils import df_from_json

# # utilize utility to make it easy to get json/dict data converted to a dataframe
# df = df_from_json(data)

# filter by countries with at least one medal and sort by total medals
df = df[df['medals.total'] > 0]
df = df.sort_values("medals.total", ascending=False)

# show top 5
df.head(5)
# Out:
#    abbr  medals.bronze  medals.gold  medals.silver  medals.total  \
# 65  RUS              7            6              8            21
# 81  USA             10            6              4            20
# 54  NLD              8            6              6            20
# 56  NOR              7            8              4            19
# 13  CAN              4            4              8            16
#
#              name
# 65   Russian Fed.
# 81  United States
# 54    Netherlands
# 56         Norway
# 13         Canada

# %%
#SKIP_COMPARE_OUTPUT
display(df, no_gen_tests='true')
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#     <div id="chartFiguref2058dca" class="pd_save is-viewer-good" style="overflow-x:auto">
#             <style type="text/css" class="pd_save">
#     .df-table-wrapper .panel-heading {
#       border-radius: 0;
#       padding: 0px;
#     }
#     .df-table-wrapper .panel-heading:hover {
#       border-color: #008571;
#     }
#     .df-table-wrapper .panel-title a {
#       background-color: #f9f9fb;
#       color: #333333;
#       display: block;
#       outline: none;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper .panel-title a:hover {
#       background-color: #337ab7;
#       border-color: #2e6da4;
#       color: #ffffff;
#       display: block;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper {
#       font-size: small;
#       font-weight: 300;
#       letter-spacing: 0.5px;
#       line-height: normal;
#       height: inherit;
#       overflow: auto;
#     }
#     .df-table-search {
#       margin: 0 0 20px 0;
#     }
#     .df-table-search-count {
#       display: inline-block;
#       margin: 0 0 20px 0;
#     }
#     .df-table-container {
#       max-height: 50vh;
#       max-width: 100%;
#       overflow-x: auto;
#       position: relative;
#     }
#     .df-table-wrapper table {
#       border: 0 none #ffffff;
#       border-collapse: collapse;
#       margin: 0;
#       min-width: 100%;
#       padding: 0;
#       table-layout: fixed;
#       height: inherit;
#       overflow: auto;
#     }
#     .df-table-wrapper tr.hidden {
#       display: none;
#     }
#     .df-table-wrapper tr:nth-child(even) {
#       background-color: #f9f9fb;
#     }
#     .df-table-wrapper tr.even {
#       background-color: #f9f9fb;
#     }
#     .df-table-wrapper tr.odd {
#       background-color: #ffffff;
#     }
#     .df-table-wrapper td + td {
#       border-left: 1px solid #e0e0e0;
#     }
#
#     .df-table-wrapper thead,
#     .fixed-header {
#       font-weight: 600;
#     }
#     .df-table-wrapper tr,
#     .fixed-row {
#       border: 0 none #ffffff;
#       margin: 0;
#       padding: 0;
#     }
#     .df-table-wrapper th,
#     .df-table-wrapper td,
#     .fixed-cell {
#       border: 0 none #ffffff;
#       margin: 0;
#       min-width: 50px;
#       padding: 5px 20px 5px 10px;
#       text-align: left;
#       word-wrap: break-word;
#     }
#     .df-table-wrapper th {
#       padding-bottom: 0;
#       padding-top: 0;
#     }
#     .df-table-wrapper th div {
#       max-height: 1px;
#       visibility: hidden;
#     }
#
#     .df-schema-field {
#       margin-left: 10px;
#     }
#
#     .fixed-header-container {
#       overflow: hidden;
#       position: relative;
#     }
#     .fixed-header {
#       border-bottom: 2px solid #000;
#       display: table;
#       position: relative;
#     }
#     .fixed-row {
#       display: table-row;
#     }
#     .fixed-cell {
#       display: table-cell;
#     }
#   </style>
#
#
#   <div class="df-table-wrapper df-table-wrapper-f2058dca panel-group pd_save">
#     <!-- dataframe schema -->
#
#     <div class="panel panel-default">
#       <div class="panel-heading">
#         <h4 class="panel-title" style="margin: 0px;">
#           <a data-toggle="collapse" href="#df-schema-f2058dca" data-parent="#df-table-wrapper-f2058dca">Schema</a>
#         </h4>
#       </div>
#       <div id="df-schema-f2058dca" class="panel-collapse collapse">
#         <div class="panel-body" style="font-family: monospace;">
#           <div class="df-schema-fields">
#             <div>Field types:</div>
#
#               <div class="df-schema-field"><strong>abbr: </strong> object</div>
#
#               <div class="df-schema-field"><strong>medals.bronze: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.gold: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.silver: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.total: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>name: </strong> object</div>
#
#           </div>
#         </div>
#       </div>
#     </div>
#
#     <!-- dataframe table -->
#     <div class="panel panel-default">
#
#       <div class="panel-heading">
#         <h4 class="panel-title" style="margin: 0px;">
#           <a data-toggle="collapse" href="#df-table-f2058dca" data-parent="#df-table-wrapper-f2058dca"> Table</a>
#         </h4>
#       </div>
#
#       <div id="df-table-f2058dca" class="panel-collapse collapse in">
#         <div class="panel-body">
#
#           <input class="df-table-search form-control input-sm" placeholder="Search table" type="text">
#
#           <div>
#
#             <span class="df-table-search-count">Showing 26 of 26 rows</span>
#
#           </div>
#           <!-- fixed header for when dataframe table scrolls -->
#           <div class="fixed-header-container">
#             <div class="fixed-header" style="width: 780px;">
#               <div class="fixed-row">
#
#                 <div class="fixed-cell" style="width: 73px;">abbr</div>
#
#                 <div class="fixed-cell" style="width: 151px;">medals.bronze</div>
#
#                 <div class="fixed-cell" style="width: 132px;">medals.gold</div>
#
#                 <div class="fixed-cell" style="width: 140px;">medals.silver</div>
#
#                 <div class="fixed-cell" style="width: 134px;">medals.total</div>
#
#                 <div class="fixed-cell" style="width: 149px;">name</div>
#
#               </div>
#             </div>
#           </div>
#           <div class="df-table-container">
#             <table class="df-table">
#               <thead>
#                 <tr>
#
#                   <th><div>abbr</div></th>
#
#                   <th><div>medals.bronze</div></th>
#
#                   <th><div>medals.gold</div></th>
#
#                   <th><div>medals.silver</div></th>
#
#                   <th><div>medals.total</div></th>
#
#                   <th><div>name</div></th>
#
#                 </tr>
#               </thead>
#               <tbody>
#
#                 <tr>
#
#                   <td>RUS</td>
#
#                   <td>7</td>
#
#                   <td>6</td>
#
#                   <td>8</td>
#
#                   <td>21</td>
#
#                   <td>Russian Fed.</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>USA</td>
#
#                   <td>10</td>
#
#                   <td>6</td>
#
#                   <td>4</td>
#
#                   <td>20</td>
#
#                   <td>United States</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>NLD</td>
#
#                   <td>8</td>
#
#                   <td>6</td>
#
#                   <td>6</td>
#
#                   <td>20</td>
#
#                   <td>Netherlands</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>NOR</td>
#
#                   <td>7</td>
#
#                   <td>8</td>
#
#                   <td>4</td>
#
#                   <td>19</td>
#
#                   <td

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='histogram',nostore_figureOnly='true',keyFields='medals.total',valueFields='medals.total',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',lineChartType='subplots',rendererId='bokeh',binsize='10',nostore_cw='1098',nostore_bokeh='true',prefix='6db8ff4c')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-6db8ff4c")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#     (function() {
#   var fn = function() {
#     Bokeh.safely(function() {
#       (function(root) {
#         function embed_document(root) {
#           var docs_json = {"a77f17b3-c0f9-47fd-89c9-bd54cf3c0200":{"roots":{"references":[{"attributes":{"overlay":{"id":"c9246685-2dc0-4124-a3ff-c21e3e5b5e11","type":"BoxAnnotation"}},"id":"4875fe87-be6c-4244-a479-9b63345efb6d","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["right","top","left"],"data":{"left":{"__ndarray__":"AAAAAAAA8D8AAAAAAAAIQAAAAAAAABRAAAAAAAAAHEAAAAAAAAAiQAAAAAAAACZAAAAAAAAAKkAAAAAAAAAuQAAAAAAAADFAAAAAAAAAM0A=","dtype":"float64","shape":[10]},"right":{"__ndarray__":"AAAAAAAACEAAAAAAAAAUQAAAAAAAABxAAAAAAAAAIkAAAAAAAAAmQAAAAAAAACpAAAAAAAAALkAAAAAAAAAxQAAAAAAAADNAAAAAAAAANUA=","dtype":"float64","shape":[10]},"top":{"__ndarray__":"2Ymd2ImduD/ZiZ3YiZ24PxQ7sRM7sbM/FDuxEzuxoz8UO7ETO7GzPwAAAAAAAAAAAAAAAAAAAAAUO7ETO7GjPwAAAAAAAAAAFDuxEzuxsz8=","dtype":"float64","shape":[10]}}},"id":"33936c3b-694b-4b49-a5d0-893ba4ba84d3","type":"ColumnDataSource"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":
type":"GlyphRenderer"}],"title":null,"toolbar":{"id":"69077826-44db-457b-9233-62d96cad2b6b","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"300d7b04-72ed-4df8-a458-424e1fb88ce6","type":"DataRange1d"},"x_scale":{"id":"904ad58e-0384-43d3-9d28-5bbdcf4dd3c6","type":"LinearScale"},"y_range":{"id":"c725e561-5589-4ff9-a980-6a8403fd9e69","type":"DataRange1d"},"y_scale":{"id":"3a892269-f0bb-4dc0-b444-6698512c01b9","type":"LinearScale"}},"id":"00f3cf31-d983-4069-a7aa-bd012a56eb84","subtype":"Figure","type":"Plot"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"scr ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_pixiedust='true',handlerId='barChart',rendererId='bokeh',keyFields='name',nostore_figureOnly='true',valueFields='medals.bronze,medals.silver,medals.gold',aggregation='SUM',rowCount='100',showLegend='true',charttype='stacked',nostore_cw='1098',nostore_bokeh='true',prefix='c24fb8dc')
# Out:
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-c24fb8dc")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#     (function() {
#   var fn = function() {
#     Bokeh.safely(function() {
#       (function(root) {
#         function embed_document(root) {
#           var docs_json = {"61370e53-1fcf-40cf-a5c5-e0be7312bf69":{"roots":{"references":[{"attributes":{"source":{"id":"66816bc1-6d6b-4efe-98a9-8a972f585312","type":"ColumnDataSource"}},"id":"11512cac-27d0-412a-be36-11427b02ed47","type":"CDSView"},{"attributes":{"fields":["medals.bronze","medals.silver"]},"id":"50e196b5-2ec5-4e64-ac8d-3bb7379d2cad","type":"Stack"},{"attributes":{},"id":"ba54f100-60d3-406f-bd2d-d7a1a6f9893f","type":"BasicTicker"},{"attributes":{"fields":["medals.bronze"]},"id":"86d89bcc-986c-4b8b-af51-4b2c1420273e","type":"Stack"},{"attributes":{"bottom":{"expr":{"id":"15e80c1b-fac5-4027-9a0c-3028ddea7150","type":"Stack"}},"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"top":{"expr":{"id":"3fce3167-55c5-4124-bb23-7763ea387618","type":"Stack"}},"width":{"value":0.9},"x":{"field":"pd_stacked_col"}},"id":"f5e740d5-fdca-4ee6-95b2-8157f8c50b2f","type":"VBar"},{"attributes":{"bottom":{"expr":{"id":"bf6da662-5eb3-4fc5-810c-31d602fdf393","type":"Stack"}},"fill_color":{"value":"#2ca02c"},"line_color":{"value":"#2ca02c"},"top":{"expr":{"id":"8300b5c2-3ec6-4ffc-a2ce-9d7ef515ce50","type":"Stack"}},"width":{"value":0.9},"x":{"field":"pd_stacked_col"}},"id":"89fa4eb7-0006-43dd-acf0-6afd186bc3f0","type":"VBar"},{"attributes":{"bottom":{"expr":{"id":"86d89bcc-986c-4b8b-af51-4b2c1420273e","type":"Stack"}},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"expr":{"id":"50e196b5-2ec5-4e64-ac8d-3bb7379d2cad","type":"Stack"}},"width":{"value":0.9},"x":{"field":"pd_stacked_col"}},"id":"c7aa7fbf-8ab9-4e54-9ef4-0b7c7e766b51","type":"VBar"},{"attributes":{"dimension":1,"plot":{"id":"1bce3193-aa50-46f4-b8d2-ed369bf66aac","subtype":"Figure","type":"Plot"},"ticker":{"id":"ba54f100-60d3-406f-bd2d-d7a1a6f9893f","type":"BasicTicker"}},"id":"b4a573f3-7ff8-47c8-8c16-95e652131302","type":"Grid"},{"attributes":{"fields":["medals.bronze","medals.silver"]},"id":"bf6da662-5eb3-4fc5-810c-31d602fdf393","type":"Stack"},{"attributes":{},"id":"1abf7dc0-eb66-43f7-862c-d92706dbc6eb","type":"LinearScale"},{"attributes":{"source":{"id":"66816bc1-6d6b-4efe-98a9-8a972f585312","type":"ColumnDataSource"}},"id":"e8867871-b07c-4b30-befb-422be63dcaab","type":"CDSView"},{"attributes":{},"id":"71d44615-45b5-49f4-ace7-d94607dd70a3","type":"ResetTool"},{"attributes":{"axis_label":"medals.bronze,medals.silver,medals.gold","formatter":{"id":"049049ef-2f5a-4cf7-9460-f20ebc4562a5","type":"BasicTickFormatter"},"minor_tick_line_color":{"value":null},"plot":{"id":"1bce3193-aa50-46f4-b8d2-ed369bf66aac","subtype":"Figure","type":"Plot"},"ticker":{"id":"ba54f100-60d3-406f-bd2d-d7a1a6f9893f","type":"BasicTicker"}},"id":"cc35faef-cad8-4565-900f-61c478a9df59","type":"LinearAxis"},{"attributes":{"fields":["medals.bronze","medals.silver","medals.gold"]},"id":"8300b5c2-3ec6-4ffc-a2ce-9d7ef515ce50","type":"Stack"},{"attributes":{"items":[{"id":"e51ff904-6ac7-46d0-96c2-650e6e75851d","type":"LegendItem"},{"id":"9fe52658-07bc-4776-93a4-b98c963a333e","type":"LegendItem"},{"id":"21e64531-a997-4738-9e99-69f54b6ed9bb","type":"LegendItem"}],"location":"top_left","plot":{"id":"1bce3193-aa50-46f4-b8d2-ed369bf66aac","subtype":"Figure","type":"Plot"}},"id":"4d7b79fa-7f28-49ff-a038-9af6f7e1a151","type":"Legend"},{"attributes":{"data_source":{"id":"66816bc1-6d6b-4efe-98a9-8a972f585312","type":"ColumnDataSource"},"glyph":{"id":"89fa4eb7-0006-43dd-acf0-6afd186bc3f0","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"4cf8ed5e-cd05-4d83-b68f-99840d2a7cf7","type":"VBar"},"selection_glyph":null,"view":{"id":"84fb94c2-ddce-413e-af0f-ca588860af3e","type":"CDSView"}},"id":"94753967-1d23-419a-a797-45a9b242b053","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"fa283a40-9c8f-4bd0-8dc5-dd5c3c7d2006","type":"BoxAnnotation"}},"id":"39a78482-3733-4bb6-80ba-739cc644d7ea","type":"BoxZoomTool"},{"attributes":{},"id":"17d1ccfc-0bba-44e0-9263-7e7f60e6b6ef","type":"WheelZoomTool"},{"attri ...

# %%
display(df,cell_id='4226511654DE46F986E04052BAF52B53',nostore_cw='1098',nostore_bokeh='false',nostore_pixiedust='true',nostore_figureOnly='true',handlerId='dataframe',prefix='67940b82')
# Out:
# <style type="text/css" class="pd_save">
#     .df-table-wrapper .panel-heading {
#       border-radius: 0;
#       padding: 0px;
#     }
#     .df-table-wrapper .panel-heading:hover {
#       border-color: #008571;
#     }
#     .df-table-wrapper .panel-title a {
#       background-color: #f9f9fb;
#       color: #333333;
#       display: block;
#       outline: none;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper .panel-title a:hover {
#       background-color: #337ab7;
#       border-color: #2e6da4;
#       color: #ffffff;
#       display: block;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper {
#       font-size: small;
#       font-weight: 300;
#       letter-spacing: 0.5px;
#       line-height: normal;
#       height: inherit;
#       overflow: auto;
#     }
#     .df-table-search {
#       margin: 0 0 20px 0;
#     }
#     .df-table-search-count {
#       display: inline-block;
#       margin: 0 0 20px 0;
#     }
#     .df-table-container {
#       max-height: 50vh;
#       max-width: 100%;
#       overflow-x: auto;
#       position: relative;
#     }
#     .df-table-wrapper table {
#       border: 0 none #ffffff;
#       border-collapse: collapse;
#       margin: 0;
#       min-width: 100%;
#       padding: 0;
#       table-layout: fixed;
#       height: inherit;
#       overflow: auto;
#     }
#     .df-table-wrapper tr.hidden {
#       display: none;
#     }
#     .df-table-wrapper tr:nth-child(even) {
#       background-color: #f9f9fb;
#     }
#     .df-table-wrapper tr.even {
#       background-color: #f9f9fb;
#     }
#     .df-table-wrapper tr.odd {
#       background-color: #ffffff;
#     }
#     .df-table-wrapper td + td {
#       border-left: 1px solid #e0e0e0;
#     }
#
#     .df-table-wrapper thead,
#     .fixed-header {
#       font-weight: 600;
#     }
#     .df-table-wrapper tr,
#     .fixed-row {
#       border: 0 none #ffffff;
#       margin: 0;
#       padding: 0;
#     }
#     .df-table-wrapper th,
#     .df-table-wrapper td,
#     .fixed-cell {
#       border: 0 none #ffffff;
#       margin: 0;
#       min-width: 50px;
#       padding: 5px 20px 5px 10px;
#       text-align: left;
#       word-wrap: break-word;
#     }
#     .df-table-wrapper th {
#       padding-bottom: 0;
#       padding-top: 0;
#     }
#     .df-table-wrapper th div {
#       max-height: 1px;
#       visibility: hidden;
#     }
#
#     .df-schema-field {
#       margin-left: 10px;
#     }
#
#     .fixed-header-container {
#       overflow: hidden;
#       position: relative;
#     }
#     .fixed-header {
#       border-bottom: 2px solid #000;
#       display: table;
#       position: relative;
#     }
#     .fixed-row {
#       display: table-row;
#     }
#     .fixed-cell {
#       display: table-cell;
#     }
#   </style>
#
#
#   <div class="df-table-wrapper df-table-wrapper-67940b82 panel-group pd_save">
#     <!-- dataframe schema -->
#
#     <div class="panel panel-default">
#       <div class="panel-heading">
#         <h4 class="panel-title" style="margin: 0px;">
#           <a data-toggle="collapse" href="#df-schema-67940b82" data-parent="#df-table-wrapper-67940b82">Schema</a>
#         </h4>
#       </div>
#       <div id="df-schema-67940b82" class="panel-collapse collapse">
#         <div class="panel-body" style="font-family: monospace;">
#           <div class="df-schema-fields">
#             <div>Field types:</div>
#
#               <div class="df-schema-field"><strong>abbr: </strong> object</div>
#
#               <div class="df-schema-field"><strong>medals.bronze: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.gold: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.silver: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>medals.total: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>name: </strong> object</div>
#
#           </div>
#         </div>
#       </div>
#     </div>
#
#     <!-- dataframe table -->
#     <div class="panel panel-default" >
#
#       <div class="panel-heading">
#         <h4 class="panel-title" style="margin: 0px;">
#           <a data-toggle="collapse" href="#df-table-67940b82" data-parent="#df-table-wrapper-67940b82"> Table</a>
#         </h4>
#       </div>
#
#       <div id="df-table-67940b82" class="panel-collapse collapse in">
#         <div class="panel-body">
#
#           <input type="text" class="df-table-search form-control input-sm" placeholder="Search table">
#
#           <div>
#
#             <span class="df-table-search-count">Showing 26 of 26 rows</span>
#
#           </div>
#           <!-- fixed header for when dataframe table scrolls -->
#           <div class="fixed-header-container">
#             <div class="fixed-header">
#               <div class="fixed-row">
#
#                 <div class="fixed-cell">abbr</div>
#
#                 <div class="fixed-cell">medals.bronze</div>
#
#                 <div class="fixed-cell">medals.gold</div>
#
#                 <div class="fixed-cell">medals.silver</div>
#
#                 <div class="fixed-cell">medals.total</div>
#
#                 <div class="fixed-cell">name</div>
#
#               </div>
#             </div>
#           </div>
#           <div class="df-table-container">
#             <table class="df-table">
#               <thead>
#                 <tr>
#
#                   <th><div>abbr</div></th>
#
#                   <th><div>medals.bronze</div></th>
#
#                   <th><div>medals.gold</div></th>
#
#                   <th><div>medals.silver</div></th>
#
#                   <th><div>medals.total</div></th>
#
#                   <th><div>name</div></th>
#
#                 </tr>
#               </thead>
#               <tbody>
#
#                 <tr>
#
#                   <td>RUS</td>
#
#                   <td>7</td>
#
#                   <td>6</td>
#
#                   <td>8</td>
#
#                   <td>21</td>
#
#                   <td>Russian Fed.</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>USA</td>
#
#                   <td>10</td>
#
#                   <td>6</td>
#
#                   <td>4</td>
#
#                   <td>20</td>
#
#                   <td>United States</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>NLD</td>
#
#                   <td>8</td>
#
#                   <td>6</td>
#
#                   <td>6</td>
#
#                   <td>20</td>
#
#                   <td>Netherlands</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>NOR</td>
#
#                   <td>7</td>
#
#                   <td>8</td>
#
#                   <td>4</td>
#
#                   <td>19</td>
#
#                   <td>Norway</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>CAN</td>
#
#                   <td>4</td>
#
#                   <td>4</td>
#
#                   <td>8</td>
#
#                   <td>16</td>
#
#                   <td>Canada</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>DEU</td>
#
#                   <td>4</td>
#
#                   <td>8</td>
#
#                   <td>3</td

# %%
#TARGET=NO_RUN
#GoogleReader has stopped working properly, disabling for now
#SKIP_COMPARE_OUTPUT
import pixiedust
import pandas as pd
from pandas_datareader import data as web
import datetime

start = datetime.date(2015,1,1)
end = datetime.date.today()

ibm = web.DataReader('IBM','google',start,end)
apple = web.DataReader('AAPL', 'google', start, end)
microsoft = web.DataReader('MSFT','google',start,end)

stocks = pd.DataFrame({"IBM": ibm['Close'],\
                      "AAPL": apple['Close'],\
                      "MSFT": microsoft['Close']})
stocks.reset_index(inplace=True)
# Out:
# /usr/local/lib/python2.7/site-packages/pandas_datareader/google/daily.py:40: UnstableAPIWarning:
# The Google Finance API has not been stable since late 2017. Requests seem
# to fail at random. Failure is especially common when bulk downloading.
#
#   warnings.warn(UNSTABLE_WARNING, UnstableAPIWarning)
# ---------------------------------------------------------------------------
# RemoteDataError                           Traceback (most recent call last)
# <ipython-input-9-643a2c1eecf9> in <module>()
#      10 end = datetime.date.today()
#      11
# ---> 12 ibm = web.DataReader('IBM','google',start,end)
#      13 apple = web.DataReader('AAPL', 'google', start, end)
#      14 microsoft = web.DataReader('MSFT','google',start,end)
#
# /usr/local/lib/python2.7/site-packages/pandas_datareader/data.pyc in DataReader(name, data_source, start, end, retry_count, pause, session, access_key)
#     313                                  chunksize=25,
#     314                                  retry_count=retry_count, pause=pause,
# --> 315                                  session=session).read()
#     316
#     317     elif data_source == "iex":
#
# /usr/local/lib/python2.7/site-packages/pandas_datareader/base.pyc in read(self)
#     204         if isinstance(self.symbols, (compat.string_types, int)):
#     205             df = self._read_one_data(self.url,
# --> 206                                      params=self._get_params(self.symbols))
#     207         # Or multiple symbols, (e.g., ['GOOG', 'AAPL', 'MSFT'])
#     208         elif isinstance(self.symbols, DataFrame):
#
# /usr/local/lib/python2.7/site-packages/pandas_datareader/base.pyc in _read_one_data(self, url, params)
#      82         """ read one data from specified URL """
#      83         if self._format == 'string':
# ---> 84             out = self._read_url_as_StringIO(url, params=params)
#      85         elif self._format == 'json':
#      86             out = self._get_response(url, params=params).json()
#
# /usr/local/lib/python2.7/site-packages/pandas_datareader/base.pyc in _read_url_as_StringIO(self, url, params)
#      93         Open url (and retry)
#      94         """
# ---> 95         response = self._get_response(url, params=params)
#      96         text = self._sanitize_response(response)
#      97         out = StringIO()
#
# /usr/local/lib/python2.7/site-packages/pandas_datareader/base.pyc in _get_response(self, url, params, headers)
#     153             msg += '\nResponse Text:\n{0}'.format(last_response_text)
#     154
# --> 155         raise RemoteDataError(msg)
#     156
#     157     def _get_crumb(self, *args):
#
# RemoteDataError: Unable to read URL: https://finance.google.com/finance/historical?q=IBM&startdate=Jan+01%2C+2015&enddate=Apr+23%2C+2018&output=csv
# Response Text:
# <html><head><meta http-equiv="content-type" content="text/html; charset=utf-8"/><title>Sorry...</title><style> body { font-family: verdana, arial, sans-serif; background-color: #fff; color: #000; }</style></head><body><div><table><tr><td><b><font face=sans-serif size=10><font color=#4285f4>G</font><font color=#ea4335>o</font><font color=#fbbc05>o</font><font color=#4285f4>g</font><font color=#34a853>l</font><font color=#ea4335>e</font></font></b></td><td style="text-align: left; vertical-align: bottom; padding-bottom: 15px; width: 50%"><div style="border-bottom: 1px solid #dfdfdf;">Sorry...</div></td></tr></table></div><div style="margin-left: 4em;"><h1>We're sorry...</h1><p>... but your computer or network may be sending automated queries. To protect our users, we can't process your request right now.</p></div><div style="margin-left: 4em;">See <a href="https://support.google.com/websearch/answer/86640">Google Help</a> for more information.<br/><br/></div><div style="text-align: center; border-top: 1px solid #dfdfdf;"><a href="https://www.google.com">Google Home</a></div></body></html>

# %%
#TARGET=NO_RUN
#SKIP_COMPARE_OUTPUT
display(stocks, no_gen_tests='true', dateFormat='%m/%d')

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='lineChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='cbd6265b')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-007fca82efb3> in <module>()
#       1 #TARGET=NO_RUN
# ----> 2 display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='lineChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='cbd6265b')
#
# NameError: name 'stocks' is not defined

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='lineChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='540af31c')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-2cca38f82a9b> in <module>()
#       1 #TARGET=NO_RUN
# ----> 2 display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='lineChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='540af31c')
#
# NameError: name 'stocks' is not defined

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='barChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='13dfaad0')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-e212330e906d> in <module>()
#       1 #TARGET=NO_RUN
# ----> 2 display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='barChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',charttype='subplots',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='13dfaad0')
#
# NameError: name 'stocks' is not defined

# %%
#TARGET=NO_RUN
display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='barChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='1e1e8556')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-b929e7bd1e8b> in <module>()
#       1 #TARGET=NO_RUN
# ----> 2 display(stocks, dateFormat='%m/%d',cell_id='C30E350068A445F9821AA5DCB2278A35',rendererId='bokeh',handlerId='barChart',keyFields='Date',valueFields='AAPL,IBM,MSFT',aggregation='AVG',rowCount='100',nostore_cw='1099',nostore_pixiedust='true',org_params='gen_tests,dateFormat',nostore_bokeh='true',prefix='1e1e8556')
#
# NameError: name 'stocks' is not defined
